# %%
import pandas as pd

articles = pd.read_csv("/content/final.csv")
q_sent = pd.read_csv("/content/HDFC.csv")

# Drop rows with invalid dates in articles
article_date_col = next((col for col in articles.columns if 'date' in col.lower()), None)
quarter_date_col = 'Date'

articles[article_date_col] = pd.to_datetime(articles[article_date_col], errors='coerce')
q_sent[quarter_date_col] = pd.to_datetime(q_sent[quarter_date_col], errors='coerce')

articles = articles.dropna(subset=[article_date_col])

# Aggregate daily news sentiment (mean)
daily_news = (
    articles
    .groupby(articles[article_date_col].dt.date)['sentiment_score']
    .mean()
    .reset_index()
    .rename(columns={article_date_col: 'Date', 'sentiment_score': 'daily_news_sentiment'})
)
daily_news['Date'] = pd.to_datetime(daily_news['Date'])

# Preserve all columns from HDFC.csv
# Merge on Date
final_df = pd.merge(q_sent, daily_news, on='Date', how='left')

# Fill days without news
final_df['daily_news_sentiment'] = final_df['daily_news_sentiment'].fillna(0)

# Save to CSV
output_path = 'final_sentiment.csv'
final_df.to_csv(output_path, index=False)

# Optionally: print or return a preview
print(final_df.head())
# Out:
#         Date           Adj Close               Close                High  \
# 0        NaT         HDFCBANK.NS         HDFCBANK.NS         HDFCBANK.NS
# 1 2022-04-01    1451.98486328125              1506.0              1510.0
# 2 2022-04-04   1597.376220703125   1656.800048828125  1722.0999755859375
# 3 2022-04-05  1550.5675048828125             1608.25   1666.699951171875
# 4 2022-04-06   1495.226318359375  1550.8499755859375   1589.800048828125
#
#                   Low                Open       Volume quarter  \
# 0         HDFCBANK.NS         HDFCBANK.NS  HDFCBANK.NS     NaN
# 1   1470.300048828125  1476.4000244140625      7284278  2023Q1
# 2   1562.550048828125              1580.0     48725485  2023Q1
# 3              1602.0   1666.699951171875     15461291  2023Q1
# 4  1547.3499755859375   1587.699951171875     13513930  2023Q1
#
#    report_sentiment  daily_news_sentiment
# 0               NaN                   0.0
# 1           0.72623                   0.0
# 2           0.72623                   0.0
# 3           0.72623                   0.0
# 4           0.72623                   0.0

# %%
final_df.dropna()
# Out:
#           Date           Adj Close               Close                High  \
# 1   2022-04-01    1451.98486328125              1506.0              1510.0
# 2   2022-04-04   1597.376220703125   1656.800048828125  1722.0999755859375
# 3   2022-04-05  1550.5675048828125             1608.25   1666.699951171875
# 4   2022-04-06   1495.226318359375  1550.8499755859375   1589.800048828125
# 5   2022-04-07   1462.349365234375             1516.75  1541.3499755859375
# ..         ...                 ...                 ...                 ...
# 673 2024-12-23              1801.0              1801.0              1806.0
# 674 2024-12-24  1798.0999755859375  1798.0999755859375   1808.699951171875
# 675 2024-12-26             1790.75             1790.75              1812.0
# 676 2024-12-27             1798.25             1798.25   1805.949951171875
# 677 2024-12-30  1777.9000244140625  1777.9000244140625              1815.0
#
#                     Low                Open    Volume quarter  \
# 1     1470.300048828125  1476.4000244140625   7284278  2023Q1
# 2     1562.550048828125              1580.0  48725485  2023Q1
# 3                1602.0   1666.699951171875  15461291  2023Q1
# 4    1547.3499755859375   1587.699951171875  13513930  2023Q1
# 5     1513.699951171875   1541.300048828125  20390866  2023Q1
# ..                  ...                 ...       ...     ...
# 673   1781.300048828125              1782.0   5522296  2025Q3
# 674   1789.550048828125   1802.050048828125   7242917  2025Q3
# 675             1780.75   1798.550048828125   5240839  2025Q3
# 676  1789.0999755859375   1794.800048828125   3629665  2025Q3
# 677              1771.0   1792.199951171875  11111109  2025Q3
#
#      report_sentiment  daily_news_sentiment
# 1            0.726230              0.000000
# 2            0.726230              0.000000
# 3            0.726230              0.000000
# 4            0.726230              0.000000
# 5            0.726230              0.000000
# ..                ...                   ...
# 673          0.770711              0.807341
# 674          0.770711              0.874686
# 675          0.770711              0.869924
# 676          0.770711              0.868356
# 677          0.770711              0.785810
#
# [677 rows x 10 columns]

# %%
final_df = final_df.drop(['Adj Close','Date','Volume','quarter'],axis="columns")

# %%
# !pip install stable-baselines3[extra] --quiet

import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gymnasium import spaces
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 16.8 MB/s eta 0:00:00

# %%
class StockTradingEnv(gym.Env):
    def __init__(self, df, window_size=5, initial_balance=10000):
        super(StockTradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.window_size = window_size
        self.initial_balance = initial_balance

        self.df["Close"] = pd.to_numeric(self.df["Close"], errors="coerce")
        self.df = self.df.dropna(subset=["Close"])

        self.feature_columns = [col for col in df.columns if col not in ['Date', 'quarter'] and df[col].dtype != 'O']
        self.num_features = len(self.feature_columns)

        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                            shape=(1 + window_size * self.num_features,), dtype=np.float32)
        self.reset()

    def _get_observation(self):
        window = self.df.loc[self.current_step - self.window_size:self.current_step - 1, self.feature_columns].values.flatten()
        obs = np.concatenate(([self.position], window), axis=0)
        return obs.astype(np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.window_size
        self.balance = self.initial_balance
        self.position = 0
        self.entry_price = 0
        self.total_profit = 0
        self.trades = 0
        self.trade_history = []
        return self._get_observation(), {}

    def step(self, action):
        terminated = False
        truncated = False
        reward = 0

        price = self.df.loc[self.current_step, "Close"]

        if action == 1 and self.position == 0:  # Buy
            self.position = 1
            self.entry_price = price
            self.trade_history.append(('Buy', self.current_step, price))

        elif action == 2 and self.position == 1:  # Sell
            profit = price - self.entry_price
            reward = profit
            self.total_profit += profit
            self.position = 0
            self.entry_price = 0
            self.trades += 1
            self.trade_history.append(('Sell', self.current_step, price))

        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            terminated = True

        return self._get_observation(), reward, terminated, truncated, {}

# %%
'''
class TrainLoggerCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.losses = []
        self.current_reward = 0

    def _on_step(self) -> bool:
        if self.locals["dones"][0]:
            self.episode_rewards.append(self.current_reward)
            self.current_reward = 0
        self.current_reward += self.locals["rewards"][0]
        if "loss" in self.locals:
            self.losses.append(self.locals["loss"].item())
        return True
'''

class TrainLoggerCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.losses = []
        self.current_reward = 0

    def _on_step(self) -> bool:
        if self.locals["dones"][0]:
            self.episode_rewards.append(self.current_reward)
            self.current_reward = 0
        self.current_reward += self.locals["rewards"][0]

        # Track loss from the replay buffer training step
        if "infos" in self.locals:
            info = self.locals["infos"][0]
            if "loss" in info:
                self.losses.append(info["loss"])

        return True

# %%
# Convert sentiment columns to numeric
final_df["report_sentiment"] = pd.to_numeric(final_df["report_sentiment"], errors="coerce")
final_df["daily_news_sentiment"] = pd.to_numeric(final_df["daily_news_sentiment"], errors="coerce")

# %%
'''
Apply a rolling z‑score (e.g. 20‑day window) to both report_sentiment and daily_news_sentiment so they’re on comparable scales.

Clip outliers (e.g. beyond ±3 σ) to stabilize learning.
'''

for col in ["report_sentiment", "daily_news_sentiment"]:
    rolling_mean = final_df[col].rolling(window=20, min_periods=1).mean()
    rolling_std = final_df[col].rolling(window=20, min_periods=1).std(ddof=0)
    final_df[f"{col}_z"] = ((final_df[col] - rolling_mean) / rolling_std).clip(-3, 3)

# %%
final_df
# Out:
#            Close         High          Low         Open  report_sentiment  \
# 0            NaN          NaN          NaN          NaN               NaN
# 1    1506.000000  1510.000000  1470.300049  1476.400024          0.726230
# 2    1656.800049  1722.099976  1562.550049  1580.000000          0.726230
# 3    1608.250000  1666.699951  1602.000000  1666.699951          0.726230
# 4    1550.849976  1589.800049  1547.349976  1587.699951          0.726230
# ..           ...          ...          ...          ...               ...
# 673  1801.000000  1806.000000  1781.300049  1782.000000          0.770711
# 674  1798.099976  1808.699951  1789.550049  1802.050049          0.770711
# 675  1790.750000  1812.000000  1780.750000  1798.550049          0.770711
# 676  1798.250000  1805.949951  1789.099976  1794.800049          0.770711
# 677  1777.900024  1815.000000  1771.000000  1792.199951          0.770711
#
#      daily_news_sentiment  report_sentiment_z  daily_news_sentiment_z
# 0                0.000000                 NaN                     NaN
# 1                0.000000                 NaN                     NaN
# 2                0.000000                 NaN                     NaN
# 3                0.000000                 NaN                     NaN
# 4                0.000000                 NaN                     NaN
# ..                    ...                 ...                     ...
# 673              0.807341                 NaN               -0.796815
# 674              0.874686                 NaN                0.396579
# 675              0.869924                 NaN                0.244616
# 676              0.868356                 NaN                0.197555
# 677              0.785810                 NaN               -1.183858
#
# [678 rows x 8 columns]

# %%
cols_to_numeric = ["Open", "High", "Low", "Close", "Adj Close", "Volume", "report_sentiment", "daily_news_sentiment"]
for col in cols_to_numeric:
    final_df[col] = pd.to_numeric(final_df[col], errors="coerce")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-11-2816442192.py in <cell line: 0>()
#       1 cols_to_numeric = ["Open", "High", "Low", "Close", "Adj Close", "Volume", "report_sentiment", "daily_news_sentiment"]
#       2 for col in cols_to_numeric:
# ----> 3     final_df[col] = pd.to_numeric(final_df[col], errors="coerce")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Adj Close'

# %%
final_df["Volume"] = final_df["Volume"].astype(str).str.replace(",", "").astype(float)

# %%
# Momentum over 5, 10, 20 days
for n in [5, 10, 20]:
    final_df[f"momentum_{n}"] = final_df["Close"].pct_change(n)

# this is for volatility over 10 and 20 days
for n in [10, 20]:
    final_df[f"volatility_{n}"] = final_df["Close"].pct_change().rolling(window=n).std()

# this is for volume flow for an indication of momentum
final_df["price_change"] = final_df["Close"].pct_change()
final_df["price_change"] = pd.to_numeric(final_df["price_change"], errors="coerce")
final_df["price_change"] = final_df["price_change"].astype(str).str.replace(",", "").astype(float)
final_df["volume_flow"] = final_df["price_change"] * final_df["Volume"]
final_df["volume_flow_ma10"] = final_df["volume_flow"].rolling(window=10).mean()

# %%
# Creating time-lagged features for last 5 days of sentiment z-scores
K = 5
for col in ["report_sentiment_z", "daily_news_sentiment_z"]:
    for lag in range(1, K + 1):
        final_df[f"{col}_lag{lag}"] = final_df[col].shift(lag)

# %%
# lot of nans cause of rolling and other functions
final_df_clean = final_df.dropna().reset_index(drop=True)

# %%
final_df_clean.to_csv("rl_ready_sentiment_features.csv", index=False)
final_df_clean
# Out:
#           Date    Adj Close        Close         High          Low  \
# 0   2022-07-08  1362.652222  1397.099976  1410.000000  1394.750000
# 1   2022-07-11  1371.479126  1406.150024  1409.900024  1393.250000
# 2   2022-07-12  1357.483032  1391.800049  1405.250000  1389.400024
# 3   2022-07-13  1324.369995  1357.849976  1394.199951  1354.250000
# 4   2022-07-14  1317.737793  1351.050049  1372.650024  1349.250000
# ..         ...          ...          ...          ...          ...
# 135 2024-10-22  1714.550049  1714.550049  1740.000000  1710.699951
# 136 2024-10-23  1735.800049  1735.800049  1746.500000  1705.050049
# 137 2024-10-24  1749.650024  1749.650024  1768.650024  1738.099976
# 138 2024-10-25  1743.400024  1743.400024  1757.849976  1728.699951
# 139 2024-10-28  1734.199951  1734.199951  1751.000000  1728.900024
#
#             Open      Volume quarter  report_sentiment  daily_news_sentiment  \
# 0    1410.000000   6237015.0  2023Q2          0.733383              0.000000
# 1    1394.000000   3731416.0  2023Q2          0.733383              0.000000
# 2    1405.250000   4938487.0  2023Q2          0.733383              0.000000
# 3    1390.000000   7972805.0  2023Q2          0.733383              0.860903
# 4    1362.000000   5186205.0  2023Q2          0.733383              0.841832
# ..           ...         ...     ...               ...                   ...
# 135  1730.050049  19437640.0  2025Q3          0.770711              0.885451
# 136  1705.050049  19018045.0  2025Q3          0.770711              0.791001
# 137  1738.099976  15416129.0  2025Q3          0.770711              0.777079
# 138  1755.000000  13065239.0  2025Q3          0.770711              0.925540
# 139  1742.000000  11006071.0  2025Q3          0.770711              0.838962
#
#      ...  report_sentiment_z_lag1  report_sentiment_z_lag2  \
# 0    ...                 1.732051                 2.000000
# 1    ...                 1.527525                 1.732051
# 2    ...                 1.362770                 1.527525
# 3    ...                 1.224745                 1.362770
# 4    ...                 1.105542                 1.224745
# ..   ...                      ...                      ...
# 135  ...                 0.654654                 0.733799
# 136  ...                 0.577350                 0.654654
# 137  ...                 0.500000                 0.577350
# 138  ...                 0.420084                 0.500000
# 139  ...                 0.333333                 0.420084
#
#      report_sentiment_z_lag3  report_sentiment_z_lag4  \
# 0                   2.380476                 3.000000
# 1                   2.000000                 2.380476
# 2                   1.732051                 2.000000
# 3                   1.527525                 1.732051
# 4                   1.362770                 1.527525
# ..                       ...                      ...
# 135                 0.816497                 0.904534
# 136                 0.733799                 0.816497
# 137                 0.654654                 0.733799
# 138                 0.577350                 0.654654
# 139                 0.500000                 0.577350
#
#      report_sentiment_z_lag5  daily_news_sentiment_z_lag1  \
# 0                   3.000000                     0.773016
# 1                   3.000000                    -0.895255
# 2                   2.380476                    -0.895255
# 3                   2.000000                    -0.808400
# 4                   1.732051                     1.175455
# ..                       ...                          ...
# 135                 1.000000                     0.326165
# 136                 0.904534                     0.675112
# 137                 0.816497                    -1.398208
# 138                 0.733799                    -1.541354
# 139                 0.654654                     1.479137
#
#      daily_news_sentiment_z_lag2  daily_news_sentiment_z_lag3  \
# 0                      -0.987840                    -0.987840
# 1                       0.773016                    -0.987840
# 2                      -0.895255                     0.773016
# 3                      -0.895255                    -0.895255
# 4                      -0.808400                    -0.895255
# ..                           ...                          ...
# 135                    -1.883487                     1.429460
# 136                     0.326165                    -1.883487
# 137                     0.675112                     0.326165
# 138                    -1.398208                     0.675112
# 139                    -1.541354                    -1.398208
#
#      daily_news_sentiment_z_lag4  daily_news_sentiment_z_lag5
# 0                       1.086763                    -0.988101
# 1                      -0.987840                     1.086763
# 2                      -0.987840                    -0.987840
# 3                       0.773016                    -0.987840
# 4                      -0.895255                     0.773016
# ..                           ...                          ...
# 135                     1.176188                     0.317386
# 136                     1.429460                     1.176188
# 137                    -1.883487                     1.429460
# 138                     0.326165                    -1.883487
# 139                     0.675112                     0.326165
#
# [140 rows x 30 columns]

# %%
final_df_clean=final_df_clean.drop(['Adj Close','Date','Volume','quarter'],axis="columns")
final_df_clean
# Out:
#            Close         High          Low         Open  report_sentiment  \
# 0    1397.099976  1410.000000  1394.750000  1410.000000          0.733383
# 1    1406.150024  1409.900024  1393.250000  1394.000000          0.733383
# 2    1391.800049  1405.250000  1389.400024  1405.250000          0.733383
# 3    1357.849976  1394.199951  1354.250000  1390.000000          0.733383
# 4    1351.050049  1372.650024  1349.250000  1362.000000          0.733383
# ..           ...          ...          ...          ...               ...
# 135  1714.550049  1740.000000  1710.699951  1730.050049          0.770711
# 136  1735.800049  1746.500000  1705.050049  1705.050049          0.770711
# 137  1749.650024  1768.650024  1738.099976  1738.099976          0.770711
# 138  1743.400024  1757.849976  1728.699951  1755.000000          0.770711
# 139  1734.199951  1751.000000  1728.900024  1742.000000          0.770711
#
#      daily_news_sentiment  report_sentiment_z  daily_news_sentiment_z  \
# 0                0.000000            1.527525               -0.895255
# 1                0.000000            1.362770               -0.895255
# 2                0.000000            1.224745               -0.808400
# 3                0.860903            1.105542                1.175455
# 4                0.841832            1.000000                1.168321
# ..                    ...                 ...                     ...
# 135              0.885451            0.577350                0.675112
# 136              0.791001            0.500000               -1.398208
# 137              0.777079            0.420084               -1.541354
# 138              0.925540            0.333333                1.479137
# 139              0.838962            0.229416               -0.241151
#
#      momentum_5  momentum_10  ...  report_sentiment_z_lag1  \
# 0      0.032022     0.031984  ...                 1.732051
# 1      0.037252     0.036793  ...                 1.527525
# 2      0.028981     0.034104  ...                 1.362770
# 3     -0.009772     0.010343  ...                 1.224745
# 4     -0.032060     0.002263  ...                 1.105542
# ..          ...          ...  ...                      ...
# 135    0.018081     0.038460  ...                 0.654654
# 136    0.021179     0.062854  ...                 0.577350
# 137    0.045722     0.052484  ...                 0.500000
# 138    0.036597     0.055966  ...                 0.420084
# 139    0.003182     0.027309  ...                 0.333333
#
#      report_sentiment_z_lag2  report_sentiment_z_lag3  \
# 0                   2.000000                 2.380476
# 1                   1.732051                 2.000000
# 2                   1.527525                 1.732051
# 3                   1.362770                 1.527525
# 4                   1.224745                 1.362770
# ..                       ...                      ...
# 135                 0.733799                 0.816497
# 136                 0.654654                 0.733799
# 137                 0.577350                 0.654654
# 138                 0.500000                 0.577350
# 139                 0.420084                 0.500000
#
#      report_sentiment_z_lag4  report_sentiment_z_lag5  \
# 0                   3.000000                 3.000000
# 1                   2.380476                 3.000000
# 2                   2.000000                 2.380476
# 3                   1.732051                 2.000000
# 4                   1.527525                 1.732051
# ..                       ...                      ...
# 135                 0.904534                 1.000000
# 136                 0.816497                 0.904534
# 137                 0.733799                 0.816497
# 138                 0.654654                 0.733799
# 139                 0.577350                 0.654654
#
#      daily_news_sentiment_z_lag1  daily_news_sentiment_z_lag2  \
# 0                       0.773016                    -0.987840
# 1                      -0.895255                     0.773016
# 2                      -0.895255                    -0.895255
# 3                      -0.808400                    -0.895255
# 4                       1.175455                    -0.808400
# ..                           ...                          ...
# 135                     0.326165                    -1.883487
# 136                     0.675112                     0.326165
# 137                    -1.398208                     0.675112
# 138                    -1.541354                    -1.398208
# 139                     1.479137                    -1.541354
#
#      daily_news_sentiment_z_lag3  daily_news_sentiment_z_lag4  \
# 0                      -0.987840                     1.086763
# 1                      -0.987840                    -0.987840
# 2                       0.773016                    -0.987840
# 3                      -0.895255                     0.773016
# 4                      -0.895255                    -0.895255
# ..                           ...                          ...
# 135                     1.429460                     1.176188
# 136                    -1.883487                     1.429460
# 137                     0.326165                    -1.883487
# 138                     0.675112                     0.326165
# 139                    -1.398208                     0.675112
#
#      daily_news_sentiment_z_lag5
# 0                      -0.988101
# 1                       1.086763
# 2                      -0.987840
# 3                      -0.987840
# 4                       0.773016
# ..                           ...
# 135                     0.317386
# 136                     1.176188
# 137                     1.429460
# 138                    -1.883487
# 139                     0.326165
#
# [140 rows x 26 columns]

# %%
from sklearn.preprocessing import StandardScaler

feature_columns = [col for col in final_df_clean.columns]

scaler = StandardScaler()
final_df_clean[feature_columns] = scaler.fit_transform(final_df_clean[feature_columns])

# %%
final_df_clean.to_csv("rl_ready_features.csv", index=False)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class LossLoggerCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.losses = []

    def _on_step(self) -> bool:
        if "train/loss" in self.logger.name_to_value:
            loss = self.logger.name_to_value["train/loss"]
            self.losses.append(loss)
        return True

loss_logger = LossLoggerCallback()

# %%
from stable_baselines3.common.callbacks import CallbackList

train_logger = TrainLoggerCallback()

loss_logger = LossLoggerCallback()

combined_callback = CallbackList([train_logger, loss_logger])

# %%
df2 = pd.read_csv("/content/rl_ready_features.csv")
df2 = df2.dropna()

env = StockTradingEnv(df2, window_size=5)
check_env(env)

logger_callback = TrainLoggerCallback()
'''
model = DQN("MlpPolicy", env, verbose=1, learning_rate=1e-4,
                           buffer_size=10000, batch_size=32, train_freq=1,
                           target_update_interval=100)
'''

model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=9e-4,              # Lower LR helps with better convergence
    buffer_size=1000,               # Bigger replay buffer means more experiecnes to learn from
    batch_size=16,   
    train_freq=4,                    
    target_update_interval=1000,     
    exploration_fraction=0.2,        
    exploration_initial_eps=0.6,     # start off with high exploration
    exploration_final_eps=0.1,      # lower final epsilon leads to more exploitation
    gamma=0.999,                    
    learning_starts=1000             # we can make sure replay buffer has a lot before learning starts

)

steps_per_episode = len(df2) - 5 - 1
total_timesteps = steps_per_episode * 200
model.learn(total_timesteps=total_timesteps, callback=combined_callback)
#model.learn(total_timesteps=10000, callback=logger_callback)
model.save("dqn_hdfc_model_changed")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 229      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 536      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00699  |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 262      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1072     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 971      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 231      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1608     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0095   |
# |    n_updates        | 1507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 231      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2144     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0356   |
# |    n_updates        | 2043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 227      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 2680     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00731  |
# |    n_updates        | 2579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 228      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 3216     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 3115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 2.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 226      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 3752     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0053   |
# |    n_updates        | 3651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 2.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 221      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 4288     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00841  |
# |    n_updates        | 4187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 2.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 222      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 4824     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00844  |
# |    n_updates        | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 3.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 224      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 5360     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 5259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 3.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 224      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 5896     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00223  |
# |    n_updates        | 5795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 3.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 223      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 6432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 6331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 3.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 211      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 6968     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 6867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 214      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 7504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 7403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 215      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 8040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00284  |
# |    n_updates        | 7939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 216      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 8576     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00432  |
# |    n_updates        | 8475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 217      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 9112     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00672  |
# |    n_updates        | 9011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 214      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 9648     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00146  |
# |    n_updates        | 9547     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 217      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 10184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 10083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 218      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 10720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00367  |
# |    n_updates        | 10619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 219      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 11256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00205  |
# |    n_updates        | 11155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 4.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 219      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 11792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 11691    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 217      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 12328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00134  |
# |    n_updates        | 12227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 217      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 12864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000643 |
# |    n_updates        | 12763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 217      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 13400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00137  |
# |    n_updates        | 13299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 218      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 13936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0033   |
# |    n_updates        | 13835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 218      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 14472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00943  |
# |    n_updates        | 14371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 217      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 15008    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 14907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 217      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 15544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000546 |
# |    n_updates        | 15443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 217      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 16080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 15979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 218      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 16616    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00227  |
# |    n_updates        | 16515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 218      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 17152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 17051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 217      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 17688    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0002   |
# |    n_updates        | 17587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 217      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 18224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000727 |
# |    n_updates        | 18123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 217      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 18760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000909 |
# |    n_updates        | 18659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 217      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 19296    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 19195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 217      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 19832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00362  |
# |    n_updates        | 19731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 217      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 20368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 20267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 217      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 20904    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00155  |
# |    n_updates        | 20803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 217      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 21440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00914  |
# |    n_updates        | 21339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 217      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 21976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000671 |
# |    n_updates        | 21875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 218      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 22512    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00182  |
# |    n_updates        | 22411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 217      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 23048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 22947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 217      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 23584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 23483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 218      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 24120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00163  |
# |    n_updates        | 24019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 218      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 24656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 24555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 218      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 25192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 25091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 217      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 25728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 25627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 217      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 26264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00245  |
# |    n_updates        | 26163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 217      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 26800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00152  |
# |    n_updates        | 26699    |
# ----------------------------------

# %%
import matplotlib.pyplot as plt

# Extracting data from callbacks using the custom loggers
rewards = train_logger.episode_rewards
losses = loss_logger.losses

# smoothing fucntion for better visibility
def smooth(data, weight=0.9):
    if not data:
        return []
    smoothed = []
    last = data[0]
    for point in data:
        smoothed_val = last * weight + (1 - weight) * point
        smoothed.append(smoothed_val)
        last = smoothed_val
    return smoothed

smoothed_rewards = smooth(rewards)
smoothed_losses = smooth(losses)

plt.figure(figsize=(12, 4))
plt.plot(rewards, label="Raw Rewards", alpha=0.4)
plt.plot(smoothed_rewards, label="Smoothed Rewards", linewidth=2)
plt.title("Episode Rewards over Time")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(losses, label="Raw Loss", alpha=0.4)
plt.plot(smoothed_losses, label="Smoothed Loss", linewidth=2)
plt.title("Training Loss over Time")
plt.xlabel("Training Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
